# %% [raw]
# # Breakouts - Week 2

# %% [markdown]
# How can we recommend the best salary for our next head football coach?

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt  # 2D plotting
# Out:
# C:\Users\datab\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Exploratory Data Analysis

# %%
raw_data = pd.read_excel("Coaches_2.xlsx")

# %%
raw_data.info()
raw_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 7 columns):
# Name           124 non-null object
# School         124 non-null object
# Conference     124 non-null object
# Salary         116 non-null float64
# OtherPay       74 non-null float64
# TotalSalary    116 non-null float64
# MaxBonus       104 non-null float64
# dtypes: float64(4), object(3)
# memory usage: 6.9+ KB
#             Name      School Conference    Salary  OtherPay  TotalSalary  \
# 0  Steve Addazio      Temple   Big East       NaN       NaN          NaN
# 1      Robb Akey       Idaho        WAC  375797.0    6200.0     381997.0
# 2  Gary Andersen  Utah State        WAC  415000.0       0.0     415000.0
# 3     Chris Ault      Nevada   Mt. West  493093.0       0.0     493093.0
# 4  David Bailiff        Rice       CUSA  608846.0       NaN     608846.0
#
#    MaxBonus
# 0       NaN
# 1  158262.0
# 2  150000.0
# 3   30000.0
# 4       NaN

# %% [markdown]
# Let's take a look at the distributions. The dataframe is small enough that we can just graph the whole thing.

# %%
sns.pairplot(raw_data, diag_kind='kde')
# kde IS BETTER IF THE DATA HAS NAs
# hist MAY BE USED IF DATA CLEANING - REMOVING / REPLACING NAs HAPPENS FIRST
# MORE HERE - https://seaborn.pydata.org/generated/seaborn.pairplot.html
plt.show()
# Out:
# C:\Users\datab\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# C:\Users\datab\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.

# %% [markdown]
# How might we add conference data?

# %%
# WILL THIS WORK?
# sns.pairplot(raw_data, diag_kind='hist', hue='Conf')
# plt.show()

# %% [markdown]
# How can we find specific observations?
# For instance - who's the guy with the $1m in 'other pay'?
# Isn't that better classified as a bonus?

# %%
raw_data[raw_data.OtherPay>5e5]
# Out:
#            Name                School Conference    Salary   OtherPay  \
# 87  Tom O'Brien  North Carolina State        ACC  936225.0  1000000.0
#
#     TotalSalary   MaxBonus
# 87    1936225.0  1110000.0
